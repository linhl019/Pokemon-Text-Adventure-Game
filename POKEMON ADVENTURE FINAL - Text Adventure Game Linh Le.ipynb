# %%
"""
Pokémon Adventure - A Text Adventure Game

Created on Wed Oct 17 2019

Author: Linh Le
"""

"""
DocString:
    
    A) Introduction:
    This game is based on the Pokémon universe, where fictional creatures 
    called Pokémon roam the wild. They are caught by human Pokémon Trainers, 
    whom raise and develop them for battle with other Pokémon for sport. 
    This game consists of four stages that require luck, reading skills,
    and possibly ethical decisions. Some knowledge of the Pokémon Universe 
    will be beneficial to the user experience.
    
    Stage 1: Catch a Pokémon 
    Stage 2: First Pokémon Battle against another Pokémon Trainer
    Stage 3: Second Pokémon Battle with Team Rocket to help your friend
    Stage 4: Evolution of your Pokémon
   
    B) Known Bugs and/or Errors:
    None.

"""

# Importing necessary packages for the game

from sys import exit
import random
import time

# Defining global variables

global user_name
global first_pokemon

# Introduction to the game

print('*' * 78)

print("""
> Oak: Hello there! Welcome to the world of Pokémon! My name is Oak!
People call me the Pokémon Prof! This world is inhabited by creatures 
called Pokémon! For some people, Pokémon are pets. Others use them for 
battles. Myself... I study Pokémon as a profession.
      """)

input('<Press Enter to continue>\n')

user_name = input("First, what is your name?\n")

# Dynamic string to change text based on what user inputted as their name

print(f"""
> Oak: Right, so your name is {user_name}! 
Well, your very own Pokémon adventure is about to unfold. 
Here is a Pokédex and three Pokéballs to get you started. 
A world of dreams and adventures with Pokémon awaits! 
Let's go!
""")

input('<Press Enter to continue>\n')

print("""

******************************************************************************

                                  ,'\\
    _.----.        ____         ,'  _\\   ___    ___     ____
_,-'       `.     |    |  /`.   \,-'    |   \  /   |   |    \  |`.
\      __    \    '-.  | /   `.  ___    |    \/    |   '-.   \ |  |
 \.    \ \   |  __  |  |/    ,','_  `.  |          | __  |    \|  |
   \    \/   /,' _`.|      ,' / / / /   |          ,' _`.|     |  |
    \     ,-'/  /   \    ,'   | \/ / ,`.|         /  /   \  |     |
     \    \ |   \_/  |   `-.  \    `'  /|  |    ||   \_/  | |\    |
      \    \ \      /       `-.`.___,-' |  |\  /| \      /  | |   |
       \    \ `.__,'|  |`-._    `|      |__| \/ |  `.__,'|  | |   |
        \_.-'       |__|    `-._ |              '-.|     '-.| |   |
                                `'                            '-._|


******************************************************************************

""")

input('<Press Enter to continue>\n')

### Stage 1: Catching the first Pokémon in the wild ###

print("""
You step out of Professor Oak's lab as pumped as ever to start your Pokémon
journey. The air feels crisper, the sky looks bluer, and...

Okay, enough with feeling great about yourself, you haven't done anything yet. 
It's time to get moving!""")

input('\n<Press Enter to continue>\n')

print("""
Surrounding Professor Oak's lab, you see a patch of high grass, a river,
and a mountain. You must now make your first decision as an official Pokémon
trainer and decide which direction to go in! 
""")

print("""
Where would you like to go?\n
1) through the high grass
2) along the river
3) towards the mountains
4) back along the dirt path that you came from
""")

# Setting different direction options the user can choose

def choose_direction(direction_1):
    
# Pairing different Pokemon the user bumps into based on what they choose as their first direction
# using dynamic strings and conditional statements

    print('*' * 78)
    global first_pokemon
    if "1" in direction_1 or "grass" in direction_1:
        first_pokemon = "Bulbasaur"
        print(f"""
Shortly after setting off through the high grass, you hear some rustling
nearby. You look towards the sound and -- according to your Pokédex, it's 
a {first_pokemon}!!
    
    
                                          /
                        _,.------....___,.' ',.-.
                     ,-'          _,.--"        |
                   ,'         _.-'              .
                  /   ,     ,'                   `
                .   /     /                     ``
       ____      |___._.  |       __               \ `.
     .'    `---""       ``"-.--"'`  \               .  \
    .  ,            __               `              |   .
    `,'         ,-"'  .               \             |    L
   ,'          '    _.'                -._          /    |
  ,`-.    ,".   `--'                      >.      ,'     |
 . .'\'   `-'       __    ,  ,-.         /  `.__.-      ,'
 ||:, .           ,'  ;  /  / \ `        `.    .      .'/
 j|:D  \          `--'  ' ,'_  . .         `.__, \   , /
/ L:_  |                 .  "' :_;                `.'.'
.    ""'                  "----'                    V
`.                                 .    `.   _,..  `
   `,_   .    .                _,-'/    .. `,'   __  `
    ) \`._        ___....----"'  ,'   .'  \ |   '  \  .
   /   `. "`-.--"'         _,' ,'     `---' |    `./  |
  .   _  `""'--.._____..--"   ,             '         |
  | ." `. `-.                /-.           /          ,
  | `._.'    `,_            ;  /         ,'          .
 .'          /| `-.        . ,'         ,           ,
 '-.__ __ _,','    '`-..___;-...__   ,.'\ ____.___.'
 `"^--'..'   '-`-^-'"--    `-^-'`.''"***`.,^.`.--' 
    
    
    """)
        input('<Press Enter to continue>\n')

    elif "2" in direction_1 or "river" in direction_1:
        first_pokemon = "Squirtle"
        print(f"""
Shortly after setting off along the river, you hear some splashing nearby.
You look towards the sound and -- according to your Pokédex, it's a 
{first_pokemon}!!

              _,........__
            ,-'            "`-.
          ,'                   `-.
        ,'                        \
      ,'                           .
      .'\               ,"".       `
     ._.'|             / |  `       \
     |   |            `-.'  ||       `.
     |   |            '-._,'||       | \
     .`.,'             `..,'.'       , |`-.
     l                       .'`.  _/  |   `.
     `-.._'-   ,          _ _'   -" \  .     `
`.""\"\""'-.`-...,---------','         `. `....__.
.'        `"-..___      __,'\           \  \     \
\_ .          |   `""|""'    `.           . \     \
  `.          |              `.          |  .     L
    `.        |`--...________.'.        j   |     |
      `._    .'      |          `.     .|   ,     |
         `--,\       .            `7""' |  ,      |
            ` `      `            /     |  |      |    _,-'"'""`-.
             \ `.     .          /      |  '      |  ,'          `.
              \  v.__  .        '       .   \    /| /              \
               \/    `""-""-""-"`.       \   \  /.''                |
                `        .        `._ ___,j.  `/ .-       ,---.     |
                ,`-.      \         ."     `.  |/        j     `    |
               /    `.     \       /         \ /         |     /    j
              |       `-.   7-.._ .          |"          '         /
              |          `./_    `|          |            .     _,'
              `.           / `----|          |-............`---'
                \          \      |          |
               ,'           )     `.         |
                7____,,..--'      /          |
                                  `---.__,--.'

    """)
        input('<Press Enter to continue>\n')
    
    elif "3" in direction_1 or "mountain" in direction_1:
        first_pokemon = "Charmander"
        print(f"""
Shortly after setting off towards the mountains, you hear some rocks
falling nearby. You look towards the sound and -- according to your Pokédex, 
it's a {first_pokemon}!!


              _.--""`-..
            ,'          `.
          ,'          __  `.
         /|          " __   \
        , |           / |.   .
        |,'          !_.'|   |
      ,'             '   |   |
     /              |`--'|   |
    |                `---'   |
     .   ,                   |                       ,".
      ._     '           _'  |                    , ' \ `
  `.. `.`-...___,...---""    |       __,.        ,`"   L,|
  |, `- .`._        _,-,.'   .  __.-'-. /        .   ,    \
-:..     `. `-..--_.,.<       `"      / `.        `-/ |   .
  `,         ""*""'     `.              ,'         |   |  ',,
    `.      '            '            /          '    |'. |/
      `.   |              \       _,-'           |       ''
        `._'               \   '"\                .      |
           |                '     \                `._  ,'
           |                 '     \                 .'|
           |                 .      \                | |
           |                 |       L              ,' |
           `                 |       |             /   '
            \                |       |           ,'   /
          ,' \               |  _.._ ,-..___,..-'    ,'
         /     .             .      `!             ,j'
        /       `.          /        .           .'/
       .          `.       /         |        _.'.'
        `.          7`'---'          |------"'_.'
       _,.`,_     _'                ,''-----"'
   _,-_    '       `.     .'      ,\
   -" /`.         _,'     | _  _  _.|
    ""--'---""-""'        `' '! |! /
                            `" " -' 

    """)
        input('<Press Enter to continue>\n')
    
    elif "4" in direction_1 or "dirt" in direction_1 or "path" in direction_1:
        first_pokemon = "Pikachu"
        print(f"""
Shortly after setting off back along the dirt path, you hear something
squeaking 'Pika!'. You look towards the sound and -- according to your Pokédex, 
it's a {first_pokemon}!!



quu..__
 $$$b  `---.__
  "$$b        `--.                          ___.---uuudP
   `$$b           `.__.------.__     __.---'      $$$$"              .
     "$b          -'            `-.-'            $$$"              .'|
       ".                                       d$"             _.'  |
         `.   /                              ..."             .'     |
           `./                           ..::-'            _.'       |
            /                         .:::-'            .-'         .'
           :                          ::''\          _.'            |
          .' .-.             .-.           `.      .'               |
          : /'$$|           .@"$\           `.   .'              _.-'
         .'|$u$$|          |$$,$$|           |  <            _.-'
         | `:$$:'          :$$$$$:           `.  `.       .-'
         :                  `"--'             |    `-.     \
        :##.       ==             .###.       `.      `.    `\
        |##:                      :###:        |        >     >
        |#'     `..'`..'          `###'        x:      /     /
         \                                   xXX|     /    ./
          \                                xXXX'|    /   ./
          /`-.                                  `.  /   /
         :    `-  ...........,                   | /  .'
         |         ``:::::::'       .            |<    `.
         |             ```          |           x| \ `.:``.
         |                         .'    /'   xXX|  `:`M`M':.
         |    |                    ;    /:' xXXX'|  -'MMMMM:'
         `.  .'                   :    /:'       |-'MMMM.-'
          |  |                   .'   /'        .'MMM.-'
          `'`'                   :  ,'          |MMM<
            |                     `'            |tbap\
             \                                  :MM.-'
              \                 |              .''
               \.               `.            /
                /     .:::::::.. :           /
               |     .:::::::::::`.         /
               |   .:::------------\       /
              /   .''               >::'  /
              `',:                 :    .'
                                   `:.:' 

        """)
        input('<Press Enter to continue>\n')

# setting an else statement as a safety net

    else:
        print("Something went wrong. Please choose a direction")
        direction_1 = input(">  ")
        direction_1 = direction_1.lower()   
        choose_direction(direction_1)

# User inputs a direction 
    
direction_1 = input(">  ")
direction_1 = direction_1.lower()    # Controlling for case sensitivity
choose_direction(direction_1) # Declaring the user's chosen direction as an object

# Catching the Pokemon

print(f"""
You have 3 Pokéballs in your inventory to catch this {first_pokemon}. 
Use them wisely!

To throw a Pokéball, guess whether the next number generated will be 
higher or lower than the previous one.
""")


# Declaring objects, namely Pokeball inventory and random number generator

pokeball_inv = 3
number_1 = random.randint(1,20)
number_2 = random.randint(1,20)

# Defining the fail statement which runs after the user runs out of Pokeballs

def fail_1():
    print("\nSorry, you ran out of Pokéballs.")
    input('\n<Press any key to exit>\n')
    exit()
    
# Making a while loop until the user is out of Pokeballs

while pokeball_inv > 0:
    
    pokeball_inv -= 1
    print("Generated number:", number_1)
    guess = input(f""" 
Do you think the next number will be higher or lower than {number_1}? 
(Please type 'higher' or 'lower'.)\n
    """)
    print("*" * 78)
    
    # making whatever the user inputs into lowercase to avoid case sensitivity
    
    guess = guess.lower()
    
    # Putting this if statement first so that it's guaranteed to run if user is out of Pokeballs
    # Takes us to the fail statement defined later
    
    if pokeball_inv == 0:
        fail_1()
    
    elif "high" in guess and number_2 > number_1 or "low" in guess and number_2 < number_1:
        print(f"\nWow! You threw a Pokéball and caught the {first_pokemon}!\n")
        input('\n<Press enter to continue>\n')
        break
    
    elif "high" in guess and number_2 < number_1 or "low" in guess and number_2 > number_1:
        print(f"\nOh no, your Pokéball missed. You have {pokeball_inv} \
Pokéball(s) left. Try again!\n")
        number_1 = random.randint(1,20)

    else:
        print("Sorry, something went wrong. Please try again.\n")
        


##### Stage 2: Battling another Pokemon #####

# Defining the second stage 

def battle_intro():
    
    global opponent
    
    print('*' * 78)
    
    # List of potential Pokemon opponents the user could battle
    
    pokemon_opp_list = ["Eevee", "Snorlax", "Beedrill"]
    opponent = random.choice(pokemon_opp_list)
    
    # Dialogue with dynamic f-strings based on randomly generated Pokemon opponent
    
    print(f"""
With your first Pokémon by your side, you continue walking, excited about 
everything that lays ahead. Suddenly, your {first_pokemon} starts going
crazy!!""")

    input('\n<Press Enter to continue>\n')

    print(f"""

> You: 'What is it, {first_pokemon}?'

Suddenly, you see it: {opponent}!""")
    
    if opponent == "Eevee":
        print("""
        

                                      |
                                     /|
                                   ,' |
                                  .   |
                                    | |
                                 ' '| |
                                / / | |
       _,.-""--._              / /  | |
     ,'          `.           j '   ' '
   ,'              `.         ||   / ,                         ___..--,
  /                  \        ' `.'`.-.,-".  .       _..---""'' __, ,'
 /                    \        \` ."`      `"'\   ,'"_..--''"-""'.'.'
.                      .      .'-'             \,' ,'         ,','
|                      |      ,`               ' .`         .' /
|                      |     /          ,"`.  ' `-. _____.-' .'
'                      |..---.|,".      | | .  .-'""   __.,-'
 .                   ,'       ||,|      |.' |    |""`'"
  `-._   `._.._____  |        || |      `._,'    |
      `.   .       `".     ,'"| "  `'           ,+.
        \  '         |    '   |   .....        .'  `.
         .'          '     7  ".              ,'     \
                   ,'      |    `..        _,'      F
                  .        |,      `'----''         |
                  |      ,"j  /                   | '
                  `     |  | .                 | `,'
                   .    |  `.|                 |/
                    `-..'   ,'                .'
                            | \             ,''
                            |  `,'.      _,' /
                            |    | ^.  .'   /
                             `-'.' j` V    /
                                   |      /
                                   |     /
                                   |   ,'


""")
    
    elif opponent == "Snorlax":
        print("""

               `:,`                                                .;+zn;                                             
              `WWW@Mzi`                                        `;+x@WMMMM                                             
              iWxxxxMW@n*.          .:;i*+**+**;:.`         .izWWMxnxxxx@`                                            
              #WxxxxnxnxMWz:   .i#xWWMMMxxxxxxMMMWWMz*:` `inWWMxxnxnxxxx@,                                            
              zWxxxxxxxxnxMWx+xWMxnnxxnnxxxxnnxxxxxxxMMWxWWxxxnnnnxxxxxx@:                                            
              zWxxxxxxxxxxxWWxxxnxxxxxnnxxxxxxxxxxxxnnnxxMWWxxxnxxxxxxxx@;                                            
              nWxnxxxxnxxWWxnxxxxxnxnxxxxxxxxxxnxxxxnnxnxxxMWWxnxxxnxxxx@;                                            
              zWxxxxnnxMWxxnxxnxMWWxxxxxxxxxxxxxnxxxMMxxxxxxxMWMxxxxxxxx@;                                            
              #WxxxxnxWMxxnnxMWz*;;nWxnnxxxxxxxxnxWM+*#MWxnnnxxWWxnnxxxx@;                                            
              +WxxxxxWMxxnxMM*......:nWxxxxxxxxMWn;.....ixWxxnxxMWxxxxxx@:                                            
              iWxxnxWxxxnxW+..........:zWxxxxMM+,.........iMMxxxnxWMnnxx@,                                            
              ;WxxxWxnnnxM:.............,#MMz;.............,zWxxxxxWMxxx@.                                            
              ,WxMWMnnnMM,...................................*WxxnxMWMxM@.                                            
              `@xWMnxxxM,.....................................iWxxxnMWxMW                                             
               WMWxxnxW:............................,,,........iWxxnxWWMM                                             
               xWMxnxWi....,i*#zzz#+;..........,+nxnnnnMxn+:....+Wxxxx@Mn                                             
               #@xxxMn..,+xx#*i;:::i+i..........:........,iz#....nMxnxWW+                                             
               zMnnxW,...:.......................................,WxnnM@:                                             
              `WxxnMz.............................................#Wnnx@:                                             
              :Wxxx@:.............:i..............::..............,WxnnW#                                             
              +Mxxxx..............Mz*............;MM...............zMnnMx                                             
              nMxxM+.............;#`n,.,,:::::,..n.+;..............iWnnx@`                                            
              WxnxW;.............*z#xMxxxnnnnxxMxM##i..............,@nxx@,                                            
             `@xxx@,.............:;,..............:i:...............WxxxW;                                            
             .@xnxW.................................................xxxxWi                                            
             ,@xxxW.................................................xxxxW*                                            
             ,@nxxW................,;;i**+++++*i;;:.................xxxxW*                                            
             ,@nnx@.........,i+zxxnz#**i;;:::;;i*+#nnnz+i,..........MxxxWi                                            
             `@xxxW:....,*zMMz*;,.....................,;+nMn*:......@xnx@;                                            
              WxxxW*.:+xWzi,...............................:+nM#;..iWnxx@.                                            
              nMxnMxxW#;......................................,*xM+nMnnMM                                             
              *WxM@ni............................................:#WWxnW#                                             
             `:@@n;................................................,+WW@:`                                            


""")
    
    elif opponent == "Beedrill":
        print("""

                     ,--""+--.
                    /     j   /`.
                   |     /   |   `.
                   |   ,'    '     \
                   j,-'     '`..    \
                  +      _ /    `._/ \
                  |     / '-.     |   .
                  |    /     |   /    |
                  |   /     j   j     |
                  |  j      |   |     |._
                  | .'     7    |     |  `.
  ___      _.._   | j      |    +     '    `.
 |.---=-.,'+-. `. |/       F     L  ,'    ,'`.
 ||,==--'|_' |  j  \      /      |,'   ,`'    L
 'Y'   | |  '/ ',.-.\    j     ,,^  _,' \     |
`.||   |  `.'  '    `.   / _,-'   `'     L   F
  ||   `     .  ,-.   `,--'              |   |
  `'    `.  /_,' ,'     `--------------""\""'Y
         _:"'_.-'       /_>:-.__           /
      `-".`"'__,`-.,-._/      `.""`------"'
      `.| `"'      | | _.--'""'--\
       || /        | '"  ___,.._  \
      _|||__      / /,.-'       `- .
    ,'   `. .    /,'/'  _.,-"-""--._F
    7     | |  .',L'|_-'           |
    +     | | / / ',"'  ,.-'""'`-._|
     L    ' |. /  .-.`"'           |
     |   j j   \  `-.'\           j
     +   | | \  `.   ` `.  _.... ,
      L  | |  \   .   `  \"     /
      | ,' |   L  ,'    \ `    .
      | || |   '  |      L `   |
      `./|j     `. .     `. \ j
       |  '       ` .     | '\`
                   \ '.   | \
                    | |  /,-'
                    j l  "
                  _/_,'
                 ',' 


""")
    
    
    input('\n<Press Enter to continue>\n')
    
    print(f"""
As you approach the {opponent}, you hear a voice yelling from behind you.

> 'HEY! What do you think you're doing?! Get away from my {opponent}!'

> You: 'Misty? Sorry, I was just passing by. I'm new to the Pokémon World, 
I didn't mean any harm!'

> Misty: '{user_name}? You're a Pokémon Trainer now? I don't trust you. 
And your {first_pokemon} seems like it's looking for a fight. 
What do you say?'\n
""") 
    
def batt_decision():
    
    # Letting the user decide if they want to battle

    battle_decision = input("Would you like to battle Misty? Y/N \n")
    battle_decision = battle_decision.lower() # Minimizing case sensitivity

    # Conditional to set the outcomes of the user's decision
    
    if "y" in battle_decision:
        print("""
> You: 'YES! Bring it on!'

> Misty: 'Alright. Since it's your first battle, you can go first.'\n

""")
        input('\n<Press Enter to continue>\n')
        battle_instr() # Brings us to the battle instructions sequence
        
    elif "n" in battle_decision:
        second_chance = input("""
Seems like you are not ready for the Pokémon World. 
Would you like to rethink that decision or forever hold your peace? Y/N
\n""")
        
        second_chance = second_chance.lower()
        
        # Nested conditional to give the user a chance to change their mind
        
        if "y" in second_chance:
            print("""
> You: 'YES! Bring it on!'

> Misty: 'Alright. Since it's your first battle, you can go first.'\n

""")
            battle_instr() # Brings us to the battle instructions sequence
            
        elif "n" in second_chance:
            print("Yeah, you're definitely not ready for the Pokémon World. Goodbye!")
            input('\n<Press any key to exit>\n')
            exit() # If user says no again, they exit the game
            
        else:
            print("Sorry, something went wrong. Please try again.\n")
            batt_decision()      
            
    else:
        print("Sorry, something went wrong. Please try again.\n")
        batt_decision()
        

# Giving the user instructions on the battle

def battle_instr():
    
    print('*' * 78)
    
    print("""
Welcome to your first Pokémon battle! Here's how it works:

Your Pokémon and your opponent's Pokémon each have 3 HP (health points).

You need to pick which one of the three attacks you would like to use on your
opponent. 

It's a risk and reward system:
Each attack does different damage to your opponent and has varying chances 
of hitting it. You must take off all 3 of your opponent's HP.
""")
    
    input("\n<Press any key to continue>\n")
    opp_health = 3
    user_health = 3
    
    while(opp_health >= 0 or user_health >= 0):
        
        opp_health = user_attack(opp_health)
        
        if opp_health <= 0:
            print("You have won the battle!!\n")
            break
        
        user_health = opp_attack(user_health)


def user_attack(opp_health):
    
    print('*' * 78)

# Conditionals for different attacks based on the different Pokemon the user may have at this point

    ## Conditional 1: BULBASAUR ##
        
    if first_pokemon == "Bulbasaur":   
        
        # Prompting user to pick their attack
        
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? \
(Please enter 1, 2, or 3.)

1. Vine Whip (1 HP damage, 100% chance of hitting)
2. Leech Seed (2 HP damage, 50% chance of hitting)
3. Razor Leaf (3 HP damage, 20% chance of hitting)
        
""")
        print('*' * 78)
            
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on BULBASAUR attacks ##
            
        if "1" in attack_choice or "vine" in attack_choice or "whip" in attack_choice:
            opp_health -= 1
            
            # Controlling for if the opponent's health runs out
            
            if opp_health <= 0:
                print('*' * 78)
                print("Misty's Pokémon has fainted!")
            
            else:
                print(f"""
Nice hit! {opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")    
        
        elif "2" in attack_choice or "leech" in attack_choice or "seed" in attack_choice:  
            variable_1 = random.randint(1, 10) 
            
            ## Nested conditional 3.0 to vary hit percentage of attack: BULBASAUR ##
            
            if variable_1 <= 5:
                opp_health -= 2
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
Awesome hit! {opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""")
                
            ## End of nested conditional 3.0 BULBASAUR ## 
        
        elif "3" in attack_choice or "razor" in attack_choice or "leaf" in attack_choice:      
            variable_2 = random.randint(1, 10)
            
            ## Nested conditional 3.1 to vary hit percentage of attack: BULBASAUR ##
            
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")    
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""")
               
            ## End of nested conditional 3.1 BULBASAUR ## 
        
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack(opp_health)

    ## End of nested conditional 1: BULBASAUR ##

    ## Start of conditional 1: SQUIRTLE ##

    elif first_pokemon == "Squirtle":           
    
        # Prompting user to pick their attack    
        
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? \
(Please enter 1, 2, or 3.)

1. Bubble (1 HP damage, 100% chance of hitting)
2. Water Gun (2 HP damage, 50% chance of hitting)
3. Hydro Pump (3 HP damage, 20% chance of hitting)
        
""")
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on SQUIRTLE attacks ##
            
        if "1" in attack_choice or "bubble" in attack_choice:
            opp_health -= 1
            
            if opp_health <= 0:
                print('*' * 78)
                print("Misty's Pokémon has fainted!")
            
            else:
                print(f"""
Nice hit! {opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")  
        
        elif "2" in attack_choice or "water" in attack_choice or "gun" in attack_choice:                
            variable_1 = random.randint(1, 10) 
            
            ## Nested conditional 3.0 to vary hit percentage of attack: SQUIRTLE ##  
            
            if variable_1 <= 5:
                opp_health -= 2
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
Awesome hit! {opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""")   
                
            ## End of nested conditional 3.0 SQUIRTLE ##
        
        elif "3" in attack_choice or "hydro" in attack_choice or "pump" in attack_choice:      
            variable_2 = random.randint(1, 10)  
            
            ## Nested conditional 3.1 to vary hit percentage of attack: SQUIRTLE ## 
            
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")    
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""") 
                
            ## End of nested conditional 3.1 SQUIRTLE ##
        
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack(opp_health)

    ## End of nested conditional 1: SQUIRTLE ##

    ## Start of nested conditional 1: CHARMANDER ##

    elif first_pokemon == "Charmander":
            
        # Prompting user to pick their attack
        
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? 
(Please enter 1, 2, or 3.)

1. Ember (1 HP damage, 100% chance of hitting)
2. Fire Spin (2 HP damage, 50% chance of hitting)
3. Flamethrower (3 HP damage, 20% chance of hitting)
        
""")
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on CHARMANDER attacks ##
            
        if "1" in attack_choice or "ember" in attack_choice:
            opp_health -= 1
            
            if opp_health <= 0:
                print('*' * 78)
                print("Misty's Pokémon has fainted!")
            
            else:
                print(f"""
Nice hit! {opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")   
        
        elif "2" in attack_choice or "fire" in attack_choice or "spin" in attack_choice:        
            variable_1 = random.randint(1, 10)  
            
            ## Nested conditional 3.0 to vary hit percentage of attack: CHARMANDER ## 
            
            if variable_1 <= 5:
                opp_health -= 2
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
Awesome hit! {opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""")
                
            ## End of nested conditional 3.0 CHARMANDER ##
        
        elif "3" in attack_choice or "flame" in attack_choice or "throw" in attack_choice:       
            variable_2 = random.randint(1, 10)
                
            ## Nested conditional 3.1 to vary hit percentage of attack: CHARMANDER ##   
            
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")    
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""")          
            
            ## End of nested conditional 3.1 CHARMANDER ##      
        
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack(opp_health)
                
    ## End of nested conditional 1: CHARMANDER ##


    ## Start of nested conditional 1: PIKACHU ##

    elif first_pokemon == "Pikachu":
           
        # Prompting user to pick their attack
            
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? 
(Please enter 1, 2, or 3.)

1. Tail Whip (1 HP damage, 100% chance of hitting)
2. Thunderbolt (2 HP damage, 50% chance of hitting)
3. Zippy Zap (3 HP damage, 20% chance of hitting)
        
""")
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on PIKACHU attacks ##
            
        if "1" in attack_choice or "tail" in attack_choice or "whip" in attack_choice:
            opp_health -= 1
            
            if opp_health <= 0:
                print('*' * 78)
                print("Misty's Pokémon has fainted!")
            
            else:
                print(f"""
Nice hit! {opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")               
        
        elif "2" in attack_choice or "thunder" in attack_choice or "bolt" in attack_choice:
                
            variable_1 = random.randint(1, 10)
                
            ## Nested conditional 3.0 to vary hit percentage of attack: PIKACHU ##
                
            if variable_1 <= 5:
                opp_health -= 2
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
    Awesome hit! {opponent} now has {opp_health} HP left.
    """)
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""")
                
            ## End of nested conditional 3.0 PIKACHU ##
            
        elif "3" in attack_choice or "zip" in attack_choice or "zap" in attack_choice:       
            variable_2 = random.randint(1, 10)
                
            ## Nested conditional 3.1 to vary hit percentage of attack PIKACHU ##
                
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print('*' * 78)
                    print("Misty's Pokémon has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")       
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {opponent} has {opp_health} HP left.
""")
            ## End of nested conditional 3.1 ##
        
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack(opp_health)
        
        ## End of nested conditional 1: PIKACHU ##
        
    return opp_health   

    
# Defining the sequence that occurs when the opponent attacks

def opp_attack(user_health):
    user_health -= 1 # Opponent attack always does a damage of 1
    
    # Making lists of the different opponents' possible attacks

    eevee_att_list = ["Iron Tail", "Tail Whip", "Double Kick"]
    eevee_att = (random.choice(eevee_att_list)) # Random attack generator 
    
    snor_att_list = ["Yawn", "Rest", "Amnesia"]
    snor_att = (random.choice(snor_att_list))
    
    bee_att_list = ["Twineedle", "Poison Jab", "Pin Missile"]
    bee_att = (random.choice(bee_att_list))
    
    # Conditional to vary opposing attacks based on type of Pokemon opponent
    
    if user_health > 0:
        
        print('*' * 78)
        
        if opponent == "Eevee":
            print(f"""
{opponent} used {eevee_att}! It did some damage. {first_pokemon} now has 
{user_health} HP left.
""")
        elif opponent == "Snorlax":
            print(f"""
{opponent} used {snor_att}! It did some damage. {first_pokemon} now has 
{user_health} HP left.
""")
        elif opponent == "Beedrill":
            print(f"""
{opponent} used {bee_att}! It did some damage. {first_pokemon} now has 
{user_health} HP left.
""")
        else:
            print("Sorry, something went wrong. Please try again.\n")
            opp_attack(user_health)
        
        input('<Press Enter to continue>\n')
            
    elif user_health <= 0:
        fail_2()
        
    return user_health  

def fail_2():
    print(f"""
Oh no! Your {first_pokemon} has no more HP and must be taken to the hospital. 
Off you go!
""")
    input("<Press any key to exit>")
    exit()
        

battle_intro()
batt_decision()


##### Stage 3: Battling Team Rocket #####

def TR_intro():
    
    global opponent
    global TR_opponent
    
    TR_opponent = "Meowth" # Only possible to battle one Pokemon this time
    
    input('\n<Press Enter to continue>\n')
    
    print('*' * 78)
    
    # Team Rocket appearance - Setting up intro to Team Rocket
    
    print(f"""
> Misty: 'Wow, I've gotta say, I'm pretty impressed. Not bad for a 
first-timer! See you around!'
""")

    input('\n<Press Enter to continue>\n')
    
    print(f"""
As you're walking away from Misty, you hear her scream 'HELP!!!!!'

You turn around and... it's Team Rocket!!! 
They're going to try to steal her {opponent}!! 

If you help her, your {first_pokemon} has a chance of evolving, but also of
fainting.
""")
    input('\n<Press Enter to continue>\n')
    
def moral_dilemma():
    
    # Letting the user decide whether they want to battle Team Rocket
    
    moral_dilemma = input(f"""
Would you like to battle Team Rocket to help Misty? Y/N \n
""")
    moral_dilemma = moral_dilemma.lower() # Minimizing case sensitivity
    
    if "y" in moral_dilemma:
        TR_battle_intro()
        
    elif "n" in moral_dilemma:
        fail_3()
        
    else:
        print("Sorry, something went wrong. Please try again.\n")
        moral_dilemma()

def TR_battle_intro():
    
    print('*' * 78)
    
    print(f"""
You run back towards Misty and Team Rocket.

> You: 'Stay away from her!!!'

> Team Rocket: 'You're cute. What is your {first_pokemon} going to do?'

> You: 'You're about to find out!'
""")
   
    input("\n<Press any key to continue>\n")
    opp_health = 3
    user_health = 3
    
    while(opp_health >= 0 or user_health >= 0):
        
        opp_health = user_attack_TR(opp_health)
        
        if opp_health <= 0:
            print("You have won the battle!!\n")
            break
        
        user_health = TR_attack(user_health)
    

def user_attack_TR(opp_health):
   
    print('*' * 78)
    
# Conditionals for different attacks based on the different Pokemon the user may have at this point

    ## Conditional 1: BULBASAUR ##
        
    if first_pokemon == "Bulbasaur":   
        
        # Prompting user to pick their attack
        
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? \
(Please enter 1, 2, or 3.)

1. Vine Whip (1 HP damage, 100% chance of hitting)
2. Leech Seed (2 HP damage, 50% chance of hitting)
3. Razor Leaf (3 HP damage, 20% chance of hitting)
        
""")
        print('*' * 78)
            
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on BULBASAUR attacks ##
            
        if "1" in attack_choice or "vine" in attack_choice or "whip" in attack_choice:
            opp_health -= 1
            
            if opp_health <= 0:
                print(f"{TR_opponent} has fainted!")
            
            else:
                print(f"""
Nice hit! {TR_opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")    
        
        elif "2" in attack_choice or "leech" in attack_choice or "seed" in attack_choice:  
            variable_1 = random.randint(1, 10) 
            
            ## Nested conditional 3.0 to vary hit percentage of attack: BULBASAUR ##
            
            if variable_1 <= 5:
                opp_health -= 2
               
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                
                else:
                    print(f"""
Awesome hit! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""")
                ## End of nested conditional 3.0 BULBASAUR ## 
                
        elif "3" in attack_choice or "razor" in attack_choice or "leaf" in attack_choice:      
            variable_2 = random.randint(1, 10)
            
            ## Nested conditional 3.1 to vary hit percentage of attack: BULBASAUR ##
           
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")    
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""")
            ## End of nested conditional 3.1 BULBASAUR ## 
                
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack_TR(opp_health)

    ## End of nested conditional 1: BULBASAUR ##

    ## Start of conditional 1: SQUIRTLE ##

    elif first_pokemon == "Squirtle":  
        
        # Prompting user to pick their attack    
    
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? \
(Please enter 1, 2, or 3.)

1. Bubble (1 HP damage, 100% chance of hitting)
2. Water Gun (2 HP damage, 50% chance of hitting)
3. Hydro Pump (3 HP damage, 20% chance of hitting)
        
""")
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on SQUIRTLE attacks ##
            
        if "1" in attack_choice or "bubble" in attack_choice:
            opp_health -= 1
            
            if opp_health <= 0:
                print(f"{TR_opponent} has fainted!")
            
            else:
                print(f"""
Nice hit! {TR_opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")  
        
        elif "2" in attack_choice or "water" in attack_choice or "gun" in attack_choice:                
            variable_1 = random.randint(1, 10) 
            
            ## Nested conditional 3.0 to vary hit percentage of attack: SQUIRTLE ##  
            
            if variable_1 <= 5:
                opp_health -= 2
                
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                else:
                    print(f"""
Awesome hit! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""")   
                
            ## End of nested conditional 3.0 SQUIRTLE ##
                
        elif "3" in attack_choice or "hydro" in attack_choice or "pump" in attack_choice:      
            variable_2 = random.randint(1, 10)  
            
            ## Nested conditional 3.1 to vary hit percentage of attack: SQUIRTLE ## 
            
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")    
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""") 
            ## End of nested conditional 3.1 SQUIRTLE ##
        
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack_TR(opp_health)
            
    ## End of nested conditional 1: SQUIRTLE ##

    ## Start of nested conditional 1: CHARMANDER ##

    elif first_pokemon == "Charmander":
            
        # Prompting user to pick their attack
            
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? 
(Please enter 1, 2, or 3.)

1. Ember (1 HP damage, 100% chance of hitting)
2. Fire Spin (2 HP damage, 50% chance of hitting)
3. Flamethrower (3 HP damage, 20% chance of hitting)
        
""")
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on CHARMANDER attacks ##
            
        if "1" in attack_choice or "ember" in attack_choice:
            opp_health -= 1
            
            if opp_health <= 0:
                print(f"{TR_opponent} has fainted!")
            
            else:
                print(f"""
Nice hit! {TR_opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")   
        
        elif "2" in attack_choice or "fire" in attack_choice or "spin" in attack_choice:        
            variable_1 = random.randint(1, 10)  
            
            ## Nested conditional 3.0 to vary hit percentage of attack: CHARMANDER ## 
            
            if variable_1 <= 5:
                opp_health -= 2
                
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                
                else:
                    print(f"""
Awesome hit! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""")
                
            ## End of nested conditional 3.0 CHARMANDER ##
        
        elif "3" in attack_choice or "flame" in attack_choice or "throw" in attack_choice:       
            variable_2 = random.randint(1, 10)
                
            ## Nested conditional 3.1 to vary hit percentage of attack: CHARMANDER ##   
            
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")    
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""")          
               
            ## End of nested conditional 3.1 CHARMANDER ##      
        
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack_TR(opp_health)
                
    ## End of nested conditional 1: CHARMANDER ##

    ## Start of nested conditional 1: PIKACHU ##

    elif first_pokemon == "Pikachu":
           
        # Prompting user to pick their attack
            
        attack_choice = input(f"""
Which attack would you like your {first_pokemon} to use? 
(Please enter 1, 2, or 3.)

1. Tail Whip (1 HP damage, 100% chance of hitting)
2. Thunderbolt (2 HP damage, 50% chance of hitting)
3. Zippy Zap (3 HP damage, 20% chance of hitting)
        
""")
        attack_choice = attack_choice.lower() # This will make limit case sensitivity of user's input
            
        ## Nested conditional 2 for different outcomes based on PIKACHU attacks ##
            
        if "1" in attack_choice or "tail" in attack_choice or "whip" in attack_choice:
            opp_health -= 1
            
            if opp_health <= 0:
                print(f"{TR_opponent} has fainted!")
            
            else:
                print(f"""
Nice hit! {TR_opponent} now has {opp_health} HP left.
""")
                input("\n<Press any key to continue>\n")               
        
        elif "2" in attack_choice or "thunder" in attack_choice or "bolt" in attack_choice:
                
            variable_1 = random.randint(1, 10)
                
            ## Nested conditional 3.0 to vary hit percentage of attack: PIKACHU ##
                
            if variable_1 <= 5:
                opp_health -= 2
                
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                
                else:
                    print(f"""
Awesome hit! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")
            
            elif variable_1 > 5:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""")
            ## End of nested conditional 3.0 PIKACHU ##
        
        elif "3" in attack_choice or "zip" in attack_choice or "zap" in attack_choice:       
            variable_2 = random.randint(1, 10)
                
            ## Nested conditional 3.1 to vary hit percentage of attack PIKACHU ##
                
            if variable_2 <= 2:
                opp_health -= 3
                
                if opp_health <= 0:
                    print(f"{TR_opponent} has fainted!")
                
                else:
                    print(f"""
CRITICAL HIT!!! {TR_opponent} now has {opp_health} HP left.
""")
                    input("\n<Press any key to continue>\n")       
            
            elif variable_2 > 2:
                print(f"""
Oh no, your attack missed! {TR_opponent} has {opp_health} HP left.
""")
            ## End of nested conditional 3.1 ##
        
        else:
            print("Sorry, something went wrong. Please try again.\n")
            user_attack_TR(opp_health)
            
    return opp_health      

    ## End of nested conditional 1: PIKACHU ##


# Defining the sequence that occurs when Team Rocket attacks

def TR_attack(user_health):
    user_health -= 1 # Opponent attack always does a damage of 1
    
    # Making a list of Meowth's attacks

    meow_att_list = ["Scratch", "Taunt", "Play Rough"]
    meow_att = (random.choice(meow_att_list))
    
    # Conditional to vary opposing attacks based on type of Pokemon opponent
    
    if user_health > 0:
        
        print(f"""
{TR_opponent} used {meow_att}! It did some damage. {first_pokemon} now has 
{user_health} HP left.
""")
        input('\n<Press Enter to continue>\n')
        
    elif user_health <= 0:
        fail_2()
        
    return user_health  

def fail_3():
    print("""You're a bad friend! Shame on you! You don't deserve to be in 
the Pokémon World. Goodbye!""")
    input("<Press any key to exit>")
    exit()

        
TR_intro()
moral_dilemma()

##### Stage 4: Pokemon Evolution #####

input("\n<Press Enter to continue>\n")

print('*' * 78)

print(f"""
> Team Rocket: 'Team Rocket blasting off again!!!!'

   *  .  . *       *    .        .        .   *    ..
 .    *        .     .      .        .            *
    *.   *   .     *      *        *    .                   
          *   *    .  *      .        .  *   .  *       *

> Misty: 'Thank you so much, {user_name}! You're the best, I owe you one!'
""")

input("\n<Press Enter to continue>\n")

print(f"""

As Misty runs off to the Pokémon Hospital, your {first_pokemon} starts 
shaking and glowing.

> You: '{first_pokemon}?? Are you okay?!'
""")

input("\n<Press Enter to continue>\n")

print("""

               ,     :     ,
          '.    ;    :    ;    ,`
      '-.   '.   ;   :   ;   ,`   ,-`
   "-.   '-.  '.  ;  :  ;  ,`  ,-`   ,-"
      "-.   '-. '. ; : ; ,` ,-`   ,-"
 '"--.   '"-.  '-.'  '  `.-`  ,-"`   ,--"`
      '"--.  '"-.   ...   ,-"`  ,--"`
           '"--.  .:::::.  ,--"`


""")

print('*' * 78)

time.sleep(3)
    
if first_pokemon == "Bulbasaur":
    print("""

                               ,'"`.,./.
                             ,'        Y',"..
                           ,'           \  | \
                          /              . |  `
                         /               | |   \
            __          .                | |    .
       _   \  `. ---.   |                | j    |
      / `-._\   `Y   \  |                |.     |
     _`.    ``    \   \ |..              '      |,-'""7,....
     l     '-.     . , `|  | , |`. , ,  /,     ,'    '/   ,'_,.-.
     `-..     `-.  : :     |/ `   ' "\,' | _  /          '-'    /___
      \""' __.,.-`.: :        /   /._    l'.,'
       `--,   _.-' `".           /__ `'-.' '         .
       ,---..._,.--"""""""--.__..----,-.'   .  /    .'   ,.--
       |                          ,':| /    | /     ;.,-'--      ,.-
       |     .---.              .'  :|'     |/ ,.-='"-.`"`' _   -.'
       /    \    /               `. :|--.  _L,"---.._        "----'
     ,' `.   \ ,'           _,     `''   ``.-'       `-  -..___,'
    . ,.  .   `   __     .-'  _.-           `.     .__    \
    |. |`        "  ;   !   ,.  |             `.    `.`'---'
    ,| |C\       ` /    | ,' |(]|            -. |-..--`
   /  "'--'       '      /___|__]        `.  `- |`.
  .       ,'                   ,   /       .    `. \
    \                      .,-'  ,'         .     `-.
     x---..`.  -'  __..--'"/""\"""  ,-.      |   |   |
    / \--._'-.,.--'     _`-    _. ' /       |     -.|
   ,   .   `-..__ ...--'  _,.-' | `   ,.-.  ;   /  '|
  .  _,'         '"-----""      |    `   | /  ,'    ;
  |-'  .-.    `._               |     `._// ,'     /
 _|    `-'   _,' "`--.._________|        `,'    _ /.
//\   ,-._.'"/\__,.   _,"     /_\__/`. /'.-.'.-/_,`-' 
`-"`"' v'    `"  `-`-"              `-'`-`  `'


Your Bulbasaur is now an Ivysaur!! 
It now has 5 HP, and has learned three new attacks: 
Solar Beam, Sleep Powder, and Mega Drain!

Congratulations!!!

""")
    
elif first_pokemon == "Squirtle":
    print("""


     __                                _.--'"7
    `. `--._                        ,-'_,-  ,'
     ,'  `-.`-.                   /' .'    ,|
     `.     `. `-     __...___   /  /     - j
       `.     `  `.-""        " .  /       /
         \     /                ` /       /
          \   /                         ,'
          '._'_               ,-'       |
             | \            ,|  |   ...-'
             || `         ,|_|  |   | `             _..__
            /|| |          | |  |   |  \  _,_    .-"     `-.
           | '.-'          |_|_,' __!  | /|  |  /           \
   ,-...___ .=                  ._..'  /`.| ,`,.      _,.._ |
  |   |,.. \     '  `'        ____,  ,' `--','  |    /      |
 ,`-..'  _)  .`-..___,---'_...._/  .'      '-...'   |      /
'.__' ""'      `.,------'"'      ,/            ,     `.._.' `.
  `.             | `--........,-'.            .         \     \
    `-.          .   '.,--""     |           ,'\        |      .
       `.       /     |          L          ,\  .       |  .,---.
         `._   '      |           \        /  .  L      | /   __ `.
            `-.       |            `._   ,    l   .    j |   '  `. .
              |       |               `"' |  .    |   /  '      .' |
              |       |                   j  |    |  /  , `.__,'   |
              `.      L                 _.   `    j ,'-'           |
               |`"---..\._______,...,--' |   |   /|'      /        j
               '       |                 |   .  / |      '        /
                .      .              ____L   \'  j    -',       /
               / `.     .          _,"     \   | /  ,-','      ,'
              /    `.  ,'`-._     /         \  i'.,'_,'      .'
             .       `.      `-..'             |_,-'      _.'
             |         `._      |            ''/      _,-'
             |            '-..._\             `__,.--'
            ,'           ,' `-.._`.            .
           `.    __      |       "'`.          |
             `-"'  `""\""'            7         `.
                                    `---'--.,'"`' 


Your Squirtle is now a Wartortle!! 
It now has 5 HP, and has learned three new attacks: 
Waterfall, Scald, and Ice Punch!

Congratulations!!!
""")
        
elif first_pokemon == "Charmander":
    print("""

                     ,-'`\
                  _,"'    j
           __....+       /               .
       ,-'"             /               ; `-._.'.
      /                (              ,'       .'
     |            _.    \             \   ---._ `-.
     ,|    ,   _.'  Y    \             `- ,'   \   `.`.
     l'    \ ,'._,\ `.    .              /       ,--. l
  .,-        `._  |  |    |              \       _   l .
 /              `"--'    /              .'       ``. |  )
.\    ,                 |                .        \ `. '
`.                .     |                '._  __   ;. \'
  `-..--------...'       \                  `'  `-"'.  \
      `......___          `._                        |  \
               /`            `..                     |   .
              /|                `-.                  |    L
             / |               \   `._               .    |
           ,'  |,-"-.   .       .     `.            /     |
         ,'    |     '   \      |       `.         /      |
       ,'     /|       \  .     |         .       /       |
     ,'      / |        \  .    +          \    ,'       .'
    .       .  |         \ |     \          \_,'        / j
    |       |  L          `|      .          `        ,' '
    |    _. |   \          /      |           .     .' ,'
    |   /  `|    \        .       |  /        |   ,' .'
    |   ,-..\     -.     ,        | /         |,.' ,'
    `. |___,`    /  `.   /`.       '          |  .'
      '-`-'     j     ` /."7-..../|          ,`-'
                |        .'  / _/_|          .
                `,       `"'/"'    \          `.
                  `,       '.       `.         |
             __,.-'         `.        \'       |
            /_,-'\          ,'        |        _.
             |___.---.   ,-'        .-':,-"`\,' .
                  L,.--"'           '-' |  ,' `-.\
                                        `.' 

Your Charmander is now a Charmeleon!! 
It now has 5 HP, and has learned three new attacks: 
Fire Blast, Dragon Pulse, and Will-O-Wisp!

Congratulations!!!

""")
    
elif first_pokemon == "Pikachu":
    print("""

                                        _,--""`---...__
                            _.---""\""`-'.   .-""\"'`-.._`-._
                _,.-----.,-"         .". `-.           "---`.
             _,' _,.-..,'__          `.'  ,-`...._      ,""''`-.
           ,' ,-'     / (  .   ,-.       |    `.  `-._  .       `.
         ,',-"       /   `"    `"'       '      .    _`. \
       ,','       ,-'7--.                 `.__."|   ( ` `j
      '.:--.    ,'   |   .       |\             '    `--'
     /.     | ,'     |   |       `'            .
    '       |',".    |._,'                     `      _.--""\"""-._
'.          `-..'    `.                      ,  \  ,-' _.-""\"""-. `.
` `                   F  -.                 /    ,' .-'          `  `
 \ `                 j     `.              ,-.   . /               . `
    `.               |     .-`.           .  '-.  V                 . `
  `   `.      .      | .    \  \         j      \/|                  ' .
   .    `.    |`.    |-.`._/`   .        |    ,'  A                  | |
    \     `. F   \   |--`  "._  |        `-.-"   / .                 | |
     \      -'    `. |        `"'                  |                 F '
      \             `+`.                           |                / .
       \              .-`                     .    j               / ,
        \              \   `.               .'    /               ' .
         \       |`._   \    `-.._        ,'    ,'              ,'.'
          '      |   `.  `.       `<`""\""'    .'             _,'.'
           `     |     `-. `._      )   `.     .          _.'_.'
            `    |        `--/     /`-._  .     `.___..--'_."
             `   |          /     /._   `""`.     `. _,.-"
              `  |         /     /   `--.....`.     `._
               ` |       ,'     /              .""\""'  `.
                `'      , `-..,7                `    . `.`.
                       .       '                 `.   \  `v
                      j.  ,   /                    `.._L_.'
                      || .   /
                      `"-'__/ 


Your Pikachu is now a Raichu!! 
It now has 5 HP, and has learned three new attacks: 
Iron Tail, Seismic Toss, and Thunder Punch!

Congratulations!!!
""")

print('*' * 78)

input("You've won the game. \nPress any key to exit")
exit()
